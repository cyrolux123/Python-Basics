# %%
print('This is my print function')
# Out:
# THis is my print function

# %%
l =[1,33,444,322,32,3,2]

# %%
len(l)
# Out:
# 7

# %%
type(l)
# Out:
# list

# %%
def test():
    pass

# %%
def test1():
    print('very first function')

# %%
test1()
# Out:
# very first function

# %%
#print returns none data type so typeerror occurs
test1() + 'cyrolux'
# Out:
# very first function
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 test1() + 'cyrolux'
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
#return returns data type as it is
def test2():
    return 'very first return '

# %%
test2()
# Out:
# 'very first return'

# %%
test2() + 'cyrolux'
# Out:
# 'very first return cyrolux'

# %%
def test3():
    return "cyro",2,22.22,[1,2,3]

# %%
test3()
# Out:
# ('cyro', 2, 22.22, [1, 2, 3])

# %%
a,b,c,d = test3()

# %%
a
# Out:
# 'cyro'

# %%
b
# Out:
# 2

# %%
c
# Out:
# 22.22

# %%
d
# Out:
# [1, 2, 3]

# %%
def test4():
    a = 5 + 6 / 7
    return a

# %%
test4()
# Out:
# 5.857142857142857

# %%
def test5(a,b,c):
    d = a + b / c
    return d

# %%
test5(2,5,8)
# Out:
# 2.625

# %%
def test6(a,b):
    return a+b

# %%
test6(3,4)
# Out:
# 7

# %%
test6('cyro','lux')
# Out:
# 'cyrolux'

# %%
test6([1,2,3],[4,5,6,7,8])
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
l = [1,3,5,6,'cyro','lux',[4,5,6,7]]

# %%
l1 = []
for i in l:
    if type(i) == int or type(i) == float:
        l1.append(i)

# %%
l1
# Out:
# [1, 3, 5, 6]

# %%
def test7(l):
    l1 = []
    for i in l:
        if type(i) == int or type(i) == float:
            l1.append(i)
    return l1

# %%
test7(l)
# Out:
# [1, 3, 5, 6]

# %%
l
# Out:
# [1, 3, 5, 6, 'cyro', 'lux', [4, 5, 6, 7]]

# %%
def test8(a):
    l1 = []
    for i in a:
        if type(i) == list:
            for j in i:
                l1.append(j)
        else:
            if type(i) == int or type(i) == float:
                l1.append(i)
    return l1

# %%
test8(l1)
# Out:
# [1, 3, 5, 6, 1, 3, 5, 6, 1, 3, 5, 6]

# %%
l1
# Out:
# [1, 3, 5, 6, 1, 3, 5, 6, 1, 3, 5, 6]

# %%
def test9(a):
    #docstring is the comment for the argument of function
    '''this is my function to extract num data from list'''
    l1 = []
    for i in a:
        if type(i) == list:
            for j in i:
                l1.append(j)
        else:
            if type(i) == int or type(i) == float:
                l1.append(i)
    return l1

# %%
test9()

# %%
def test10(a,b):
    return a + b

# %%
test10(1,2)
# Out:
# 3

# %%
def test11(*args):
    return args

# %%
test11()
# Out:
# ()

# %%
type(test11())
# Out:
# tuple

# %%
test11(1,3,5)
# Out:
# (1, 3, 5)

# %%
test11(2,3,'cyro',(2,3,4))
# Out:
# (2, 3, 'cyro', (2, 3, 4))

# %%
type(test11())
# Out:
# tuple

# %%
def test12(*cyro):
    return cyro

# %%
test12(3,4,4.4)
# Out:
# (3, 4, 4.4)

# %%
def test13(*args,a):
    return args,a

# %%
test13(1,3,4, a = 22)
# Out:
# ((1, 3, 4), 22)

# %%
test13(1,3,44,a = 22)
# Out:
# ((1, 3, 44), 22)

# %%
def test14(c ,d, a = 23, b =1 ):
    return a,b,c,d

# %%
test14()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 test14()
#
# TypeError: test14() missing 2 required positional arguments: 'c' and 'd'

# %%
test14(3,44)
# Out:
# (23, 1, 3, 44)

# %%
test14(2,5, a = 11)
# Out:
# (11, 1, 2, 5)

# %%
def test15(**kwargs):
    return kwargs

# %%
test15()
# Out:
# {}

# %%
type(test15())
# Out:
# dict

# %%
test15(a = [1,3,4] , b = 'cyro' , c = 12.12)
# Out:
# {'a': [1, 3, 4], 'b': 'cyro', 'c': 12.12}

# %%
n = 3

p = 2

# %%
def test(n,p):
    return n ** p

# %%
test(3,2)
# Out:
# 9

# %%
a = lambda n,p : n **p

# %%
a(3,2)
# Out:
# 9

# %%
add = lambda x,y : x + y

# %%
add(4,5)
# Out:
# 9

# %%
c2f = lambda c : (9/5)*c + 32

# %%
c2f(25)
# Out:
# 77.0

# %%
c2f(5)
# Out:
# 41.0

# %%
c2f(45)
# Out:
# 113.0

# %%
max = lambda x,y : x if x>y else y

# %%
max(4,44)
# Out:
# 44

# %%
s = 'cyrolux'

# %%
length = lambda s : len(s)

# %%
length(s)
# Out:
# 7
